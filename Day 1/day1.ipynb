# %%
import sqlite3

# %%
type(sqlite3)
# Out:
# module

# %%
conn = sqlite3.connect("first.db")

# %%
cur = conn.cursor()

# %%
cur.execute("""
    CREATE TABLE ice_cream_flavors (
        id INTEGER PRIMARY KEY,
        flavor TEXT,
        rating INTEGER
        );
        """)

# %%
cur.execute("""
    INSERT INTO ice_cream_flavors (flavor,rating)
    VALUES('chocolate',10), ('strawberry',9),('pistachio',7.3);
    """)

# %%
conn.commit()

# %%
cur.execute("SELECT * FROM ice_cream_flavors");

# %%
cur.fetchone()
# Out:
# (1, 'chocolate', 10)

# %%
cur.fetchone()
# Out:
# (2, 'strawberry', 9)

# %%
cur.fetchone()
# Out:
# (3, 'pistachio', 7.3)

# %%
cur.fetchall()
# Out:
# [(1, 'chocolate', 10), (2, 'strawberry', 9), (3, 'pistachio', 7.3)]

# %%
cur.fetchmany()
# Out:
# [(1, 'chocolate', 10)]

# %%
cur.execute("SELECT * FROM ice_cream_flavors")

for row in cur:
    print(row)
# Out:
# (1, 'chocolate', 10)
# (2, 'strawberry', 9)
# (3, 'pistachio', 7.3)

# %%
cur.execute("SELECT * FROM ice_cream_flavors")

cur.fetchmany(2)
# Out:
# [(1, 'chocolate', 10), (2, 'strawberry', 9)]
